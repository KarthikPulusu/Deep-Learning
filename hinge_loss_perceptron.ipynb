# %%
from sklearn.datasets import make_classification
X,y=make_classification(n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,n_samples=100,random_state=42,hypercube=False,class_sep=15)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=y)

# %%
def perceptron(X,y):
    w1=w2=b=1
    lr=0.1
    for j in range(1000):
        for i in range(X.shape[0]):
            z=w1*X[i][0]+w2*X[i][1]+b

            if z*y[i]<0:
                w1=w1+lr*y[i]*X[i][0]
                w2=w2+lr*y[i]*X[i][1]
                b=b+lr*y[i]
    return w1,w2,b

# %%
w1,w2,b=perceptron(X,y)

# %%
b
# Out:
# 1

# %%
w1,w2
# Out:
# (1, 1)

# %%
m=-(w1/w2)
c=-(b/w2)
print(m,c)
# Out:
# -1.0 -1.0

# %%
import numpy as np
X_input=np.linspace(-3,3,100)
y_input=m*X_input+c

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X[:,0],X[:,1],c=y)
plt.plot(X_input, y_input, color='red')
plt.ylim(-20,20)
# Out:
# (-20.0, 20.0)

# %%
# Your code is mostly correct for implementing a simple perceptron and plotting the decision boundary.
# However, there are a few things to note:
# 1. The perceptron algorithm expects the labels to be -1 and 1, not 0 and 1. 
#    If y contains 0 and 1, you should convert 0 to -1 before training.
# 2. The perceptron will only converge if the data is linearly separable, which is the case here.
# 3. Your plotting and calculation of the decision boundary are correct.

# Let's check the labels:
print("Unique labels in y:", np.unique(y))

# If you see [0 1], convert 0 to -1:
if set(np.unique(y)) == {0, 1}:
    y = np.where(y == 0, -1, 1)
    # You may want to rerun the perceptron training after this conversion.
    w1, w2, b = perceptron(X, y)
    m = -(w1 / w2)
    c = -(b / w2)
    print("Updated slope and intercept:", m, c)
# Out:
# Unique labels in y: [0 1]
# Updated slope and intercept: -1.0 -1.0
